# %%
using ITensors
using ITensorMPS
using PolyChaos
using LinearAlgebra
using Plots
using Observers
using DSP

# %%
using ITensors
using ITensorMPS
using PolyChaos
using LinearAlgebra

"""
Struct definitions for parameters
"""

Base.@kwdef struct BathParameters
    Γ::Float64 #Coupling to system
    β::Float64 #inverse temperature
    μ::Float64 #chemical potential
    D::Float64 #bandwidth
    N::Int     #Number of chain modes
end

Base.@kwdef struct SystemParameters
    ϵ::Vector{Float64} #Vector of onsite energies
    t::Vector{Float64} #Vector of couplings
    U::Vector{Float64} #Vector of interactions
    occupations::Vector{String} # Vector of initial occupations
end

Base.@kwdef struct TDVP_parameters
    tdvp_cutoff::Float64 #Numerical cutoff for tdvp
    minbonddim::Int      #Minimum bond dimension for tdvp
    maxbonddim::Int      #Maximum bond dimension for tdvp
    δt::Float64          #Time step
    total_simulation_time::Float64 #Evolution time
end


abstract type ThermofieldSector end
struct Filled <: ThermofieldSector end
struct Empty <: ThermofieldSector end

struct ChainLayout

    left_filled
    left_empty

    system

    right_filled
    right_empty
end


"""
Initialisation functions
"""

fermi_factor(ω,β,μ) = 1 / (exp(β*(ω-μ)) + 1)
heaviside(t) = 0.5 * (sign.(t) .+ 1)

function semicircular_density(Γ,ω,D)
    J = real((2*Γ/(π^2))*sqrt.(Complex.(1 .-(ω/D).^2)))
    return J

end

function box_spectral_density(Γ,ω,D)
    #Box spectral density
    return J = (Γ/(2*π))*(heaviside(ω .+ D) .- heaviside(ω .- D))
end

function thermofield_spectral_density(ω,bath::BathParameters,::Filled)
    #Spectral density for a filled chain
    J = box_spectral_density(bath.Γ,ω,bath.D)
   # J = semicircular_density(bath.Γ,ω,bath.D)
    return J * fermi_factor(ω,bath.β,bath.μ)
end

function thermofield_spectral_density(ω,bath::BathParameters,::Empty)
    #Spectral density for an empty chain
    J = box_spectral_density(bath.Γ,ω,bath.D)
  #  J = semicircular_density(bath.Γ,ω,bath.D)
    return J * (1 - fermi_factor(ω,bath.β,bath.μ))
end

function chain_mapping(bath::BathParameters,sector::ThermofieldSector)

    #Calculates the chain coefficients using PolyChaos.jl

    spec_fun(ω) = thermofield_spectral_density(ω,bath,sector)

    #support needs to be larger than spectral function for numerical reasons.
    support = (-2*bath.D,2*bath.D)

    meas = Measure("thermofield",spec_fun,support,false,Dict())
    op = OrthoPoly("chain",bath.N-1,meas;Nquad=100000)

    α = coeffs(op)[:,1]
    β = coeffs(op)[:,2]

    return α,sqrt.(β)
end

function ChainLayout(N_left_bath,N_right_bath,Nsys)
    ##Arranges the chains in interleaved fashion, with the system at the centre

    N = 2*(N_left_bath+N_right_bath) + Nsys

    ChainLayout(
        1:2:2*N_left_bath,
        2:2:2*N_left_bath,
        2*N_left_bath+1:2*N_left_bath+Nsys,
        2*N_left_bath+Nsys+1:2:N,
        2*N_left_bath+Nsys+2:2:N,
    )
end

function add_chain(H,os,inds,energies,hoppings)
    ##Adds MPO terms and associated single particle hamiltonian elements 
    ##for the thermofield chain

    N = length(inds)
    for i in 1:N
        os += energies[i],"N",inds[i]

        H[inds[i],inds[i]] = energies[i]

        if i < N
            t = hoppings[i]
            os += t,"Cdag",inds[i],"C",inds[i+1]
            os += t,"Cdag",inds[i+1],"C",inds[i]

            H[inds[i],inds[i+1]] = t
            H[inds[i+1],inds[i]] = t
        end
    end
    return H,os
end

function couple_sites(H,os,i,j,t)
    #Couples two sites, used for the system-chain coupling

    os += t,"Cdag",i,"C",j
    os += t,"Cdag",j,"C",i

    H[i,j] = t
    H[j,i] = t
    return H,os
end

function build_hamiltonian(sites,left,right,sys)
    #builds single particle hamiltonian and many body MPO

    layout =ChainLayout(left.N,right.N,length(sys.ϵ))
    N = length(sites)
    Hsingle = zeros(ComplexF64,N,N)
    os = OpSum()

    #chain coefficients for the four chains
    εLF,tLF =chain_mapping(left,Filled())
    εLE,tLE =chain_mapping(left,Empty())
    εRF,tRF =chain_mapping(right,Filled())
    εRE,tRE =chain_mapping(right,Empty())

    #adds the terms for the chains
    Hsingle,os = add_chain(Hsingle,os,layout.left_filled,reverse(εLF),reverse(tLF))
    Hsingle,os = add_chain(Hsingle,os,layout.left_empty,reverse(εLE),reverse(tLE))
    Hsingle,os = add_chain(Hsingle,os,layout.right_filled,εRF,tRF[2:end])
    Hsingle,os = add_chain(Hsingle,os,layout.right_empty,εRE,tRE[2:end])


    #
    # system
    #

    for i in eachindex(sys.ϵ)
        ##energies
        os += sys.ϵ[i],"N",layout.system[i]
        Hsingle[layout.system[i],layout.system[i]] = sys.ϵ[i]
        if i < length(sys.ϵ)
            #hoppings
            Hsingle,os = couple_sites(Hsingle,os,layout.system[i],layout.system[i+1],sys.t[i])
            #interactions
            os += sys.U[i],"N",layout.system[i],"N",layout.system[i+1]
        end
    end

    #
    # bath-system couplings
    #

    Hsingle,os = couple_sites(Hsingle,os,last(layout.left_filled),first(layout.system),first(tLF))
    Hsingle,os = couple_sites(Hsingle,os,last(layout.left_empty),first(layout.system),first(tLE))
    Hsingle,os = couple_sites(Hsingle,os,first(layout.right_filled),last(layout.system),first(tRF))
    Hsingle,os = couple_sites(Hsingle,os,first(layout.right_empty),last(layout.system),first(tRE))
    return MPO(os,sites), Hsingle,os
end

function thermofield_vacuum(left,right,system)
    #defines the initial state given both baths have an interleaved ordering
    #for the filled and empty chains. Both start with the filled mode from the left.

    Nbath = left.N
    Nsys = length(system.ϵ)
    left_bath_occ =[isodd(i) ? "Emp" : "Occ" for i in 1:2*left.N]
    right_bath_occ =[isodd(i) ? "Emp" : "Occ" for i in 1:2*right.N]
    sys_occ = system.occupations

    return [left_bath_occ;sys_occ;right_bath_occ]
end


#Evolution functions

function current_time(; current_time, bond, half_sweep)
    if bond == 1 && half_sweep == 2
    return real(im*current_time)
    end
    return nothing
end
function measure_correlation_matrix(; state, bond, half_sweep)
    if bond==1 && half_sweep == 2
        return correlation_matrix(state,"Cdag","C")
    end
    return nothing
end
function propagate_correlations(corr0,H_single,times)
    
    """
    The correlation matrix C_ij = expect(cdag[j]*c[i]) propagates according to
    C_ij(t) =U*C_ij(0)*U', but G_ij = expect(cdag[i]*c[j]) doesn't.
    
    # This is also why the returned correlation matrices are transposed, as we want the output to be the standard definition
    # G_ij = expect(cdag[i]*c[j]).
    """

    δt = times[2] - times[1]
    U_step = exp(-im*δt*H_single)

    corrs = Vector{Any}(undef,length(times))
    corrs[1] = U_step*corr0*U_step'
    for i in 2:length(times)
        corrs[i] = U_step*corrs[i-1]*U_step'
    end
    return transpose.(corrs)
end
function LB_current(left,right,system)
    
    """
    Calculates the steady state particle current Jp of a system 
    using the Landauer-Büttiker formalism. This assumes both baths have the same spectral function, given by the box function.
    """

    eta = 0.005 
    wsamp = 10000; # Frequency sampling.
    w = range(-10*left.D,10*left.D,wsamp); # Frequency axis for Landauer calculations (larger than the band).
    Γ = left.Γ+right.Γ
    dw = w[2] - w[1]; # Frequency increment.


    ρ = (1/(2*left.D))*(heaviside(w .+ left.D) .- heaviside(w .- left.D))
    Δ_L = (-left.Γ/(2*π))*log.((w.-left.D .+im*eta)./(w .+left.D .+im*eta))    #exact result (only valid for box)
    Δ_R = (-right.Γ/(2*π))*log.((w.-right.D .+im*eta)./(w .+right.D .+im*eta)) #exact result (only valid for box)
        # Δ_L = -im*left.D*left.Γ*hilbert(ρ) #more generally
        # Δ_R = -im*left.D*right.Γ*hilbert(ρ) #more generally


    ####Calculate determinant of M matrix (N_sys x N_sys)
    N_sys = length(system.ϵ)
    if N_sys == 1
        Δ = Δ_L + Δ_R
        detM = w .- system.ϵ[1] .- Δ
        G = 1 ./detM
        A_den = (-1/π).*imag.(G)    
    elseif N_sys == 2
        detM = (w .-system.ϵ[1] .-Δ_L).*(w.-system.ϵ[2].-Δ_R)
        detM = detM .- abs.(system.t[1]^2) 
        G = ((w .-system.ϵ[2] .-Δ_R))./detM
        A_den = (-1/π).*imag.(G)    
    elseif N_sys == 3
        detM = (w .-system.ϵ[1] .-Δ_L).*(w.-system.ϵ[3].-Δ_R).*(w.-system.ϵ[2])
        detM = detM - (abs.(system.t[2])^2)*(w.-system.ϵ[1].-Δ_L)
        detM = detM - (abs.(system.t[1])^2)*(w.-system.ϵ[3].-Δ_R)
        G =  (w .-system.ϵ[1] .-Δ_L).*(w.-system.ϵ[3].-Δ_R)./detM
        A_den = (-1/π)*imag.(G)
    end

    A = (left.D*Γ*ρ/π) ./(abs.(detM).^2)
    if length(system.t)>0
        coupling_factor = prod(abs.(system.t).^2)
        A = A.*coupling_factor
    end    
    f_L = fermi_factor.(w,left.β,left.μ)
    f_R = fermi_factor.(w,right.β,right.μ)

    prefactor = (4*π*left.D*left.Γ*right.Γ)/(2*π*Γ)
    Jp = prefactor*sum(ρ.*A.*(f_L - f_R))*dw;

    return Jp
end
# Out:
# LB_current (generic function with 1 method)

# %%
"""
Define parameters
"""

left_bath = BathParameters(Γ = 0.5,β = 10.0,μ = 0.1,D = 1.0,N =2)

right_bath = BathParameters(Γ = 0.5,β = 10.0,μ = -0.1,D = 1.0,N = 2)

system = SystemParameters(ϵ = [0.0],t = [0.1],U = [0.0],occupations=["Emp"])

time_evolution = TDVP_parameters(tdvp_cutoff = 1e-9,minbonddim = 20,maxbonddim = 20,δt = 0.01,total_simulation_time = 1)

times = range(time_evolution.δt,stop = time_evolution.total_simulation_time,step = time_evolution.δt)

"""
Create initial MPS
"""
sites = siteinds("Fermion",2*left_bath.N+2*right_bath.N + length(system.ϵ);conserve_qns=true)
ψ0 = MPS(ComplexF64,sites,thermofield_vacuum(left_bath,right_bath,system))

"""
Create single particle Hamiltonian and many-body MPO
"""

H_MPO,H_single,os =build_hamiltonian(sites,left_bath,right_bath,system);


"""
TDVP
"""

#create observer for tdvp
obs = Observer("times" => current_time,"corr" => measure_correlation_matrix)


ψT = tdvp(H_MPO, -im * time_evolution.total_simulation_time, ψ0; 
time_step = -im * time_evolution.δt,
cutoff = time_evolution.tdvp_cutoff, 
mindim = time_evolution.minbonddim, 
maxdim = time_evolution.maxbonddim, 
outputlevel = 1, 
observer! = obs)



"""
Exact correlation matrix evolution (only valid for U=0)
"""
corr0 = correlation_matrix(ψ0,"Cdag","C")
exact_corrs = propagate_correlations(corr0,H_single,times);
# Out:
# After sweep 1: maxlinkdim=4 maxerr=7.77E-16 current_time=0.0 - 0.01im time=0.234
# After sweep 2: maxlinkdim=14 maxerr=5.91E-20 current_time=0.0 - 0.02im time=0.19
# After sweep 3: maxlinkdim=16 maxerr=4.68E-17 current_time=0.0 - 0.03im time=0.455
# After sweep 4: maxlinkdim=16 maxerr=1.51E-18 current_time=0.0 - 0.04im time=0.437
# After sweep 5: maxlinkdim=16 maxerr=1.92E-18 current_time=0.0 - 0.05im time=0.445
# After sweep 6: maxlinkdim=16 maxerr=5.36E-23 current_time=0.0 - 0.06im time=0.433
# After sweep 7: maxlinkdim=16 maxerr=1.97E-19 current_time=0.0 - 0.07im time=0.431
# After sweep 8: maxlinkdim=16 maxerr=1.41E-19 current_time=0.0 - 0.08im time=0.424
# After sweep 9: maxlinkdim=16 maxerr=1.45E-21 current_time=0.0 - 0.09im time=0.426
# After sweep 10: maxlinkdim=16 maxerr=2.43E-18 current_time=0.0 - 0.1im time=0.445
# After sweep 11: maxlinkdim=16 maxerr=2.24E-18 current_time=0.0 - 0.11im time=0.438
# After sweep 12: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.12im time=0.453
# After sweep 13: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.13im time=0.435
# After sweep 14: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.14im time=0.445
# After sweep 15: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.15im time=0.433
# After sweep 16: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.16im time=0.434
# After sweep 17: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.17im time=0.434
# After sweep 18: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.18im time=0.429
# After sweep 19: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.19im time=0.429
# After sweep 20: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.2im time=0.435
# After sweep 21: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.21im time=0.438
# After sweep 22: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.22im time=0.441
# After sweep 23: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.23im time=0.436
# After sweep 24: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.24im time=0.436
# After sweep 25: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.25im time=0.427
# After sweep 26: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.26im time=0.435
# After sweep 27: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.27im time=0.43
# After sweep 28: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.28im time=0.463
# After sweep 29: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.29im time=0.464
# After sweep 30: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.3im time=0.449
# After sweep 31: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.31im time=0.484
# After sweep 32: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.32im time=0.481
# After sweep 33: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.33im time=0.465
# After sweep 34: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.34im time=0.473
# After sweep 35: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.35im time=0.45
# After sweep 36: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.36im time=0.474
# After sweep 37: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.37im time=0.462
# After sweep 38: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.38im time=0.518
# After sweep 39: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.39im time=0.468
# After sweep 40: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.4im time=0.493
# After sweep 41: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.41im time=0.481
# After sweep 42: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.42im time=0.49
# After sweep 43: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.43im time=0.461
# After sweep 44: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.44im time=0.848
# After sweep 45: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.45im time=0.589
# After sweep 46: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.46im time=0.565
# After sweep 47: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.47im time=0.476
# After sweep 48: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.48im time=0.482
# After sweep 49: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.49im time=0.488
# After sweep 50: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.5im time=0.491
# After sweep 51: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.51im time=0.489
# After sweep 52: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.52im time=0.501
# After sweep 53: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.53im time=0.5
# After sweep 54: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.54im time=0.5
# After sweep 55: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.55im time=0.518
# After sweep 56: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.56im time=0.46
# After sweep 57: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.57im time=0.482
# After sweep 58: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.58im time=0.507
# After sweep 59: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.59im time=0.508
# After sweep 60: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.6im time=0.506
# After sweep 61: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.61im time=0.512
# After sweep 62: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.62im time=0.507
# After sweep 63: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.63im time=0.512
# After sweep 64: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.64im time=0.524
# After sweep 65: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.65im time=0.51
# After sweep 66: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.66im time=0.511
# After sweep 67: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.67im time=0.476
# After sweep 68: maxlinkdim=16 maxerr=6.66E-16 current_time=0.0 - 0.68im time=0.446
# After sweep 69: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.69im time=0.452
# After sweep 70: maxlinkdim=16 maxerr=8.88E-16 current_time=0.0 - 0.7im time=0.493
# After sweep 71: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.71im time=0.513
# After sweep 72: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.72im time=0.514
# After sweep 73: maxlinkdim=16 maxerr=8.88E-16 current_time=0.0 - 0.73im time=0.547
# After sweep 74: maxlinkdim=16 maxerr=6.66E-16 current_time=0.0 - 0.74im time=0.499
# After sweep 75: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.75im time=0.48
# After sweep 76: maxlinkdim=16 maxerr=6.66E-16 current_time=0.0 - 0.76im time=0.491
# After sweep 77: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.77im time=0.485
# After sweep 78: maxlinkdim=16 maxerr=6.66E-16 current_time=0.0 - 0.78im time=0.455
# After sweep 79: maxlinkdim=16 maxerr=8.89E-16 current_time=0.0 - 0.79im time=0.444
# After sweep 80: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.8im time=0.443
# After sweep 81: maxlinkdim=16 maxerr=8.88E-16 current_time=0.0 - 0.81im time=0.434
# After sweep 82: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.82im time=0.442
# After sweep 83: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.83im time=0.455
# After sweep 84: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.84im time=0.465
# After sweep 85: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.85im time=0.48
# After sweep 86: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.86im time=0.448
# After sweep 87: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.87im time=0.475
# After sweep 88: maxlinkdim=16 maxerr=6.66E-16 current_time=0.0 - 0.88im time=0.467
# After sweep 89: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.89im time=0.455
# After sweep 90: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.9im time=0.449
# After sweep 91: maxlinkdim=16 maxerr=7.78E-16 current_time=0.0 - 0.91im time=0.478
# After sweep 92: maxlinkdim=16 maxerr=6.67E-16 current_time=0.0 - 0.92im time=0.496
# After sweep 93: maxlinkdim=16 maxerr=7.78E-16 current_time=0.0 - 0.93im time=0.441
# After sweep 94: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.94im time=0.466
# After sweep 95: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.95im time=0.462
# After sweep 96: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.96im time=0.489
# After sweep 97: maxlinkdim=16 maxerr=6.67E-16 current_time=0.0 - 0.97im time=0.451
# After sweep 98: maxlinkdim=16 maxerr=8.89E-16 current_time=0.0 - 0.98im time=0.498
# After sweep 99: maxlinkdim=16 maxerr=7.77E-16 current_time=0.0 - 0.99im time=0.466
# After sweep 100: maxlinkdim=16 maxerr=7.78E-16 current_time=0.0 - 1.0im time=0.47

# %%
corr_tdvp = correlation_matrix(ψT,"Cdag","C")
corr_exact = exact_corrs[end]
Δ = corr_tdvp - corr_exact
heatmap(abs.(Δ))

# %%
"""
Plotting
"""
#site to look at for density/current
sys_site = 1
MPS_site = 2*left_bath.N+sys_site

tdvp_den = [corr[MPS_site,MPS_site] for corr in obs.corr] 
tdvp_currents = real.([im*(system.t[sys_site]*corr[MPS_site+1,MPS_site] - system.t[sys_site]*corr[MPS_site,MPS_site+1]) for corr in obs.corr])

exact_den = real.([corr[MPS_site,MPS_site] for corr in exact_corrs])
exact_currents = real.([im*(system.t[sys_site]*corr[MPS_site+1,MPS_site] - system.t[sys_site]*corr[MPS_site,MPS_site+1]) for corr in exact_corrs])


plot(times,real.(tdvp_den),label="tdvp")
display(plot!(times,real.(exact_den),label="Exact"))


# plot(times,exact_currents,label="Exact currents")
# plot!(times,tdvp_currents,label="TDVP currents")
# display(plot!(times,real.(LB_current(left_bath,right_bath,system)*ones(length(times))),label="Exact steady state"))
